# %% [markdown]
# # Libraries Used

# %%
import pandas as pd
import tweepy
import requests
import gensim
import gensim.corpora as corpora
import re
import emoji
import nltk
import os
import pyLDAvis.gensim_models as gensimvis
import pickle 
import pyLDAvis
import warnings
import en_core_web_md
import spacy # need have spacy version >=3.2.3
import en_core_web_trf
from spacy_entity_linker import EntityLinker
from spacy.language import Language
from access_token import tokens
from wordcloud import WordCloud
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from pprint import pprint
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# ignore warnings for now
warnings.filterwarnings("ignore")

# may need to download a few packages
# !pip install spacy
# !pip install tweepy
# !pip install wordcloud
# !pip install gensim
# !pip install pyldavis
# !pip install vaderSentiment
# !pip install spacy-transformers
# !pip install spacy-entity-linker
# !python -m spacy download en_core_web_trf  ### 460 MB
# !python -m spacy download en_core_web_md   ### 30 MB
# !python -m spacy_entity_linker download "knowledge_base"
# !pip install spacy-entity-linker

# %% [markdown]
# # Configuring Twitter API

# %%
# auth = tweepy.OAuthHandler(tokens['api_token'], tokens['api_token_secret'])
# auth.set_access_token(tokens['access_token'], tokens['access_token_secret'])

auth = tweepy.OAuth1UserHandler(tokens['api_token'], tokens['api_token_secret'], tokens['access_token'], tokens['access_token_secret'])
api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# # Use Pandas DataFrame to store downloaded tweets

# %%
# Collect tweets
# set query 
query = "#trump" + " -filter:retweets"

# set date of which queries were created until
cutoff_date = "2022-03-19"

# get tweets at a specified number
tweets = tweepy.Cursor(api.search_tweets, q=query, lang="en", until=cutoff_date).items(200)

# get tweets information, in a form of date, user, location, text
tweets_list = [[tweet.created_at, tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]

# convert to dataframe
tweets_df = pd.DataFrame(data=tweets_list, columns=['date', 'user', 'location', 'text'])

# %%
tweets_df
# Out:
#                          date            user       location  \
# 0   2022-03-18 23:59:04+00:00    sosajoejr559     Hanford CA
# 1   2022-03-18 23:59:01+00:00         W_Mead_
# 2   2022-03-18 23:58:57+00:00     LegalLining  The Big Apple
# 3   2022-03-18 23:58:33+00:00    RedCacheONLY
# 4   2022-03-18 23:58:00+00:00       Theboveed
# ..                        ...             ...            ...
# 195 2022-03-18 23:01:29+00:00    DorothyBeach      Ohio, USA
# 196 2022-03-18 23:00:46+00:00    randomtrump1
# 197 2022-03-18 23:00:34+00:00         cozharz           Troy
# 198 2022-03-18 23:00:07+00:00  DemActionToday
# 199 2022-03-18 23:00:00+00:00       c_baschan
#
#                                                   text
# 0    45th President Donald J. Trump to Hold a Rally...
# 1    @MarshaBlackburn #trump and the @GOP already t...
# 2    Russia prepared Trump to be Putin's Puppet for...
# 3    Alex Jones on why Full Send Podcast Trump Inte...
# 4    Donald Trump wants his supporters to carry Tru...
# ..                                                 ...
# 195  @JudiciaryDems An honor that was not given to ...
# 196  Random Trump https://t.co/wIrKt8Vmsq - #random...
# 197  This #atheist murderous KGB #dictator quoted #...
# 198  @mazemoore #PutinsPuppet https://t.co/QNNLLMpQ...
# 199  Critical Race Theory explained by John Oliver ...
#
# [200 rows x 4 columns]

# %%
tweets_df.to_csv ('test.csv', quotechar='"', encoding='utf8', index = False, header=True)

# %% [markdown]
# # Data Cleaning

# %%
# # Uncomment the line below if loading from previously saved CSV
tweets_df = pd.read_csv('test.csv', quotechar='"', encoding='utf8')

# Remove hyperlinks
tweets_df['text'] = tweets_df['text'].map(lambda x: re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', x))

# Remove punctuation
tweets_df['text'] = tweets_df['text'].map(lambda x: re.sub('[,\\!?…]', ' ', x))

# Remove unnecessary line breaks
tweets_df['text'] = tweets_df['text'].map(lambda x: re.sub(r"\n", '', x))

# Convert the titles to lowercase
tweets_df['text'] = tweets_df['text'].map(lambda x: x.lower())

# Remove emojis
tweets_df['text'] = tweets_df['text'].map(lambda x: emoji.demojize(x))

# store the processed tweets to csv
tweets_df.to_csv ('test_cleaned.csv', quotechar='"', encoding='utf8', index = False, header=True)

# %% [markdown]
# # Exploration using a word cloud

# %%
# get all tweets without duplication
unique_tweets = list(set(list(tweets_df['text'].values)))
unique_tweets = [t for t in unique_tweets if t]

# join the words of the different tweets together into one string
long_string = ' '.join(unique_tweets)
new_long_string = ' '.join(set(long_string.split(" ")))

# create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# generate a word cloud
wordcloud.generate(new_long_string)

# visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1F6B3FA71F0>

# %% [markdown]
# # Topic Modelling

# %% [markdown]
# ### Configuring Stopwords

# %%
# get stopwords from nltk library, without outputing the download information to terminal
nltk.download('stopwords', quiet=True)

stop_words = stopwords.words('english')

# add more stopwords
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# get the tweets in a list
data = tweets_df.text.values.tolist()

data_words = list(sent_to_words(data))

# remove stop words
data_words = remove_stopwords(data_words)

# %% [markdown]
# ### Visualise the topics

# %%
# create a dictionary
id2word = corpora.Dictionary(data_words)

# create a corpus
texts = data_words

# convert the corpus into a BoW representation
corpus = [id2word.doc2bow(text) for text in texts]

# set number of topics
num_topics = 5

# build an LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=id2word, num_topics=num_topics)

# print keywords in each topic
# pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

pyLDAvis.enable_notebook()

LDAvis_data_filepath = os.path.join('./'+str(num_topics))

LDAvis_prepared = gensimvis.prepare(lda_model, corpus, id2word)

# uncomment this if you want to save LDAvis_prepared file
# with open(LDAvis_data_filepath, 'wb') as f:
#     pickle.dump(LDAvis_prepared, f)
# f.close()

# with open(LDAvis_data_filepath, 'rb') as f:
#     LDAvis_prepared = pickle.load(f)
# f.close()

pyLDAvis.save_html(LDAvis_prepared, './saved_topics.html')

LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.036423  0.110760       1        1  26.700731
# 2     -0.075000 -0.088865       2        1  24.187657
# 0      0.152630 -0.018663       3        1  19.935518
# 4     -0.028360 -0.011365       4        1  19.430195
# 3     -0.012847  0.008133       5        1   9.745900, topic_info=           Term        Freq       Total Category  logprob  loglift
# 296     ukraine   28.000000   28.000000  Default  30.0000  30.0000
# 7         trump  143.000000  143.000000  Default  29.0000  29.0000
# 525       aides    9.000000    9.000000  Default  28.0000  28.0000
# 162        says    6.000000    6.000000  Default  27.0000  27.0000
# 359  clown_face    7.000000    7.000000  Default  26.0000  26.0000
# ..          ...         ...         ...      ...      ...      ...
# 453       msnbc    0.634192    2.459125   Topic5  -5.7113   0.9731
# 333   political    0.634186    2.405288   Topic5  -5.7114   0.9952
# 0        donald    0.634160    3.201454   Topic5  -5.7114   0.7093
# 535        gets    0.634135    2.557140   Topic5  -5.7114   0.9339
# 111        seen    0.634003    1.779746   Topic5  -5.7116   1.2962
#
# [283 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 95        2  0.541560  administration
# 95        5  0.541560  administration
# 592       3  0.761381              ai
# 525       2  0.107146           aides
# 525       3  0.857168           aides
# ...     ...       ...             ...
# 795       2  0.758996            went
# 63        1  0.295321           would
# 63        3  0.738302           would
# 89        1  0.722372             yes
# 766       1  0.740903             yrs
#
# [355 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 1, 5, 4])

# %% [markdown]
# # Sentiment Analysis

# %%
analyzer = SentimentIntensityAnalyzer()

for tweet_text in unique_tweets:
    vs = analyzer.polarity_scores(tweet_text)
    print(tweet_text + '\n' + str(vs))
    print()
# Out:
# this #atheist murderous kgb #dictator quoted #scripture 2 rally his #russian people in support of his #warcrimes. w
# {'neg': 0.183, 'neu': 0.699, 'pos': 0.118, 'compound': -0.3612}
#
# i am actually not sure it is such a threat to her political career. if #trump is found guilty of misusing public fu
# {'neg': 0.404, 'neu': 0.596, 'pos': 0.0, 'compound': -0.9163}
#
# @noliewithbtc interesting that #lavrov is such a fan of #trump  @tuckercarlson and @foxnews. #foxnews cameraman p
# {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.6124}
#
# now...now... be fair. #trump suggest injecting sunshine and bleach.  you have to give him credit for originality on
# {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.7964}
#
# navy seals gang up on nancy pelosi  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# via @crooksandliars: house progressives give biden a wish list of executive orders  | #trump #gop #republicans
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4019}
#
# #january6th and #science and #trump and #america and #democrats and #usa and #freedom and #trumpguilty and
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6369}
#
# @costavjw @pigriffs @redhorse6531 @phoenixwildish @omega7stone @flblueslayer @calltrixie @agent35512 @katibug957
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @ronfilipkowski #trump supporters are
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
#
# msm is a joke  hunter biden's laptop was and is real joke and :clown_face::clown_face::clown_face::clown_face::clown_face:#laptopfromhell#hunterbidenlaptop
# {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.5267}
#
# @potus are you still alive  where is #trump
# {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.3818}
#
# @fpwellman idiocracy: a disturbingly prophetic look at the future of america – and our era of stupidity
# {'neg': 0.292, 'neu': 0.708, 'pos': 0.0, 'compound': -0.7351}
#
# mcconnell pulls apart "the big lie"  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# pelosi’s closet swings wide open  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @sjgs_2021 @1joav @maclinx @mary1kathy @rotterdamvvg @enespacio @e_snacks @baconbacon1969 @dmbfangrl76 @koan4uu
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @marshablackburn #trump and the @gop already transformed the #scotus by appointments to forward their radical agend
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #trump was the only reason i was interested in politics. what a man
# {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.4019}
#
# joe biden is 'drowning' in his home state  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# senator kennedy accuses biden of “illegal” action  #maga #trump2024 #trump
# {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.34}
#
# via @rawstory: scott pruitt seeks trump's endorsement to launch political comeback in oklahoma: report
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.3182}
#
# "lame duck pelosi" sabotaged by her own party  #maga #trump2024 #trump
# {'neg': 0.193, 'neu': 0.621, 'pos': 0.186, 'compound': -0.0258}
#
# @evankopelson i would like lesley stahl to do a story on trump pushing false rumors about a joe scarborough aid bei
# {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3612}
#
# @donniedarkened @conan_esq #god refused to help #trump retake the throne in 2020  so now his #magats turn to #satan.  sounds about right.
# {'neg': 0.085, 'neu': 0.731, 'pos': 0.185, 'compound': 0.3818}
#
# #trump doing 'business' in #scotland - 2011 bulldozing locals to build his golf course.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @tuckercarlson  #trump and all the rest of these nobodies are the lying  hypocritical  a$$bags. let's boot them fro
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.7506}
#
# congress collides with major investigation  #maga #trump2024 #trump
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.2732}
#
# #jesus delivers us from the cares of this world  not the other way around. #putinswar  #trump #letitgo
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4588}
#
# @soulibird @suziebird4 @vixey_picklejar @sicilianal @cherylbluewave @3sidecarsplz @winners786 @shoathree
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# same thing @caslernoel has been trying to tell us for years  helloooo    who hasn't been paying attention
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #democrats say #putin and #trump are just alike  does anyone think #trump would just give up and walk away or agree
# {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.3612}
#
# the five fox news 3/18 22 | fox breaking news  @judgejeanine #china @foxnews #ukraine
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @taylormadebride @tomthunkitsmind @thegreathouseco @jillfano2 @jewell35_a @mathhatter1 @livetrudi @lsutigers12345
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @rosskneedeep yes. and putin has tapes. #trump
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
#
# @mazemoore #putinspuppet #clinton #trump debate#tedcruz on #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @vantahku @zarleckazpa @bzliberal @donalynette @dreamthesailor @musicistheory @indivisprescott @inderisme
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @georgetakei :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kil
# {'neg': 0.105, 'neu': 0.895, 'pos': 0.0, 'compound': -0.25}
#
# biden and trump clash head-on  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# via @rawstory: watch: ohio gop senate candidates get in each others' faces during heated primary debate
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @suziebird4 @soulibird @vixey_picklejar @sicilianal @cherylbluewave @3sidecarsplz @winners786 @shoathree
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @msnbc china will do what china wants to do. made in china missiles should never go to putin #impeachtrumpagain
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @duty2warn yes  chris but  as america is still clinging to #democracy power comes from the people. and do you reall
# {'neg': 0.0, 'neu': 0.911, 'pos': 0.089, 'compound': 0.2144}
#
# how to make a conservative angry: lie to them.how to make a liberal angry: tell them the truth.#liberal #biden
# {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compound': -0.765}
#
# @black2thbone @skvl75 @scott_5d @garym27 @vegix @polarsprite @lizmoblubuckeye @klglass2 @steveanders_11 @ps9714
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @dtimes17 @yamaatsu2311 :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aide
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.25}
#
# 45th president donald j. trump to hold a rally in michigan #trumprally #michigan #potus45 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @lecarrigg @60minutes i would like lesley stahl to do a story on trump pushing false rumors about a joe scarborough
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.3612}
#
# @johnpavlovitz “the media desperately wants another #trump presidencytheir livelihoods thrive on the sideshowthey
# {'neg': 0.168, 'neu': 0.71, 'pos': 0.123, 'compound': -0.1779}
#
# freedom truckers just turned the tables  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}
#
# virginia republican ag just cleaned house  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #lesliestahl should apologize to #trump she was wrong and should admit it. if she doesn’t her reporting will always
# {'neg': 0.139, 'neu': 0.717, 'pos': 0.143, 'compound': -0.2263}
#
# trump asked his ag about legal strategy to overturn election  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'compound': 0.128}
#
# another #friday news dump and #hunter in it again. maybe this time. prediction: harris steps down  killary installe
# {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'compound': -0.3818}
#
# #trump lapdog mark meadows  who never lived where said he did on his voter registration  is worried about voters mo
# {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.296}
#
# the gloves are coming off :boxing_glove:#election2022 is coming up fast and @jfradio is keeping you updated. john says the tur
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #trump has a #hearttoheart with #biden #bidenflation #letsgobrandon
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #facts49%of americans are  how do i say it nicely  dumbasses. #trump is a mastermind if you are a dumbass
# {'neg': 0.153, 'neu': 0.723, 'pos': 0.123, 'compound': -0.1779}
#
# wow  finally  the bgng of the end  dominoes are falling    the truth always comes to light    #jesusisthetruth
# {'neg': 0.074, 'neu': 0.645, 'pos': 0.281, 'compound': 0.6705}
#
# @ek7_prn when #trump was president and "forced" to shut down the economy  i knew something was fishy because that i
# {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.4588}
#
# federal judge drops green gavel on biden  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# manchin sets the record straight on biden’s bill  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2263}
#
# #trump’s ex-chief of staff mark #meadows investigated for #voter #registration #fraud. north carolina authorities a
# {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.5859}
#
# @dtimes17 :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kill p
# {'neg': 0.283, 'neu': 0.717, 'pos': 0.0, 'compound': -0.7717}
#
# biden goes head to head with trump and obama  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @livepddave1 lol #trump is not one for apologizing when he intentionally smears innocent citizens with false stor
# {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.6621}
#
# another trump:U.S._Outlying_Islands: rally april 2 2022 at 7:00 pm. awesome  #trump #trumprally #jesusandtrump
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.6249}
#
# supreme court frontrunner’s closet swings open  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.5574}
#
# @lovemykiaram @repairrestores1 @cynthiaharless1 @rainfery @pandazed @bec2yeg @standforbetter @randomlygeorge @jeber
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# supreme court delivers 5-4 decision  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.5574}
#
# more of my #poetry#bodyparts:  #thetrumpyears: #amazon #poems
# {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.1779}
#
# @acyn :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kill putin
# {'neg': 0.283, 'neu': 0.717, 'pos': 0.0, 'compound': -0.7717}
#
# @joncoopertweets they are both equal both have killed - #ukraine  and #trump killed on #january6thinsurrection
# {'neg': 0.409, 'neu': 0.591, 'pos': 0.0, 'compound': -0.875}
#
# trump election poll shakes up 2024 race  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @syd_ayers @donmoyn it's exactly what #putin and other #dictators do. "fake news" is anything unfavorable to him. y
# {'neg': 0.154, 'neu': 0.846, 'pos': 0.0, 'compound': -0.4767}
#
# @niabbot @lbc i’m a scotsman making pasta  listening in houston  texas. so good to have you back. #trumpson will so
# {'neg': 0.0, 'neu': 0.835, 'pos': 0.165, 'compound': 0.5777}
#
# @scrantonville @grayzpoo @marisoltorresrs @tcrg2012 @doingjack @silenced777 @lizfortx8 @amymcgrathky @racismloses
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# her ⁦@cbsnews⁩ #cbsnews ⁦@60minutes⁩ goal was to defeat @gop #trump watch: cbs news reporter falsely told donald
# {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.4588}
#
# #fbr i follow back those who believe #trump is a #chump#votebluein2022 #arresttrumpnow#joebiden is #decent unlike 45
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #conservative #rightwing pundits know they’re presenting a fucked up definition of our #firstamendment #freespeech
# {'neg': 0.253, 'neu': 0.747, 'pos': 0.0, 'compound': -0.6597}
#
# the only disaster is you  #trump  @tedcruz &amp; your nazi party
# {'neg': 0.259, 'neu': 0.57, 'pos': 0.171, 'compound': -0.34}
#
# @christianwalk1r can u imagine a black kid backing #trump &amp; #gop despite what they do to....black americans. oh wai
# {'neg': 0.0, 'neu': 0.942, 'pos': 0.058, 'compound': 0.0258}
#
# icymi: "‘putin’ us on: why dems’ ‘russian disinformation’ claims can’t be taken seriously" #trump #donaldtrump
# {'neg': 0.108, 'neu': 0.892, 'pos': 0.0, 'compound': -0.1779}
#
# mass manipulation in #russiaas well as m of #americans believe #trump's #biglie  m of #russian believe the
# {'neg': 0.114, 'neu': 0.777, 'pos': 0.109, 'compound': -0.0258}
#
# #trump perfect call
# {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'compound': 0.5719}
#
# this totally explains why steve harvey met with #trump at trump tower in 2016. i understand completely.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @gop never forget trump gave us 14% unemployment. @repmtg @mattgaetz @repandybiggsaz  @repboebert @massieforky
# {'neg': 0.186, 'neu': 0.707, 'pos': 0.107, 'compound': -0.3036}
#
# @logicfirst1 @antman0528 @logicturn the #trump police in action.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# omg  #putin &amp; #trump are of the same cloth: narcissistic sociopathic pathological liars with egos so large they mak
# {'neg': 0.159, 'neu': 0.841, 'pos': 0.0, 'compound': -0.5267}
#
# do anyone of you think thatmark ruffalo cares about how many peoplefamilies have had to cut back on other things
# {'neg': 0.091, 'neu': 0.779, 'pos': 0.13, 'compound': 0.2263}
#
# aoc’s republican rival just landed lots of blue support  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'compound': 0.4019}
#
# biden impeachment threat goes through the roof  #maga #trump2024 #trump
# {'neg': 0.274, 'neu': 0.726, 'pos': 0.0, 'compound': -0.5267}
#
# @dtimes17 @toshihikoogata :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says ai
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.25}
#
# biden plummets in swing state he won in 2020  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.5719}
#
# alex jones on why full send podcast trump interview really got deleted...#alexjones #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @logicfirst1 so did you drink disinfectants  take horse de-wormer or insert uv light in your anus like #trump told
# {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
#
# nancy pelosi goes back on her word  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# icymi: "ballot bombshells: 20 episodes exposing fraud  illegalities and irregularities in 2020 election" #trump
# {'neg': 0.33, 'neu': 0.67, 'pos': 0.0, 'compound': -0.7096}
#
# so when #trump was president people wanted to build a wall between #usa and #mexico this same people wanne crawl ov
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @steveanders_11 @doingjack @dprobbob @dejafuuled @laney2003us @pmurttrump @new_allyo @katibug817 @resisterclaire
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# alex jones show – 03/18/2022 – economic collapse and nuclear war are only the beginning
# {'neg': 0.353, 'neu': 0.647, 'pos': 0.0, 'compound': -0.7964}
#
# @d_jeneration the only problem i see is that free speech gives #foxnews #trump &amp; #gop the freedom to spew #russian
# {'neg': 0.099, 'neu': 0.625, 'pos': 0.276, 'compound': 0.7003}
#
# random trump  - #randomtrump #trump #donaldtrump #giphy #gif #gifs
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 45th president donald j. trump to hold a rally in michigan #trump #donaldtrump #republican #conservative #trump2024
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @sorayaresist @ritamacmom @texy_liz @srh_medco @rosannaphillip @sugardonaghy @sawmcdargh @wipapa5 @vintageknits
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @loudevoyce apologize for what  asking questions given #trump maliciously spread false rumors about private citiz
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1027}
#
# "adam schiff" continues tolie to voters. this bozo spent4yrs only attacking #trump.#congress #senate #covid#biden #covid
# {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4588}
#
# hunter biden’s laptop anyone  #trump #biden #hunterbiden #ukraine #russia #russiahoax
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @novelection2024 no... but #trump's coup on january 6th is the "crime of the century."#trumpisarussianasset
# {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'compound': -0.6956}
#
# @magosaki_ukeru :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.25}
#
# @jackposobiec he’s safe in office now so it’s ok to #stealtheelection. like #clinton won’t face charges for spying
# {'neg': 0.088, 'neu': 0.584, 'pos': 0.329, 'compound': 0.6983}
#
# shabbos dinner.  that shiksa melania sat me in between lauren boebert &amp; her husband.when he isn't trying to show
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @dtimes17 @tsujimotokiyomi @hamakoto @shirai_satoshi @rqnr_20c :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides tr
# {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'compound': -0.25}
#
# pelosi gets served major lawsuit by trump ally  #maga #trump2024 #trump
# {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.2944}
#
# @reaidonjtrump_ there is no #trump administration. he is in the dustbin of history just spewing out his grievances
# {'neg': 0.227, 'neu': 0.773, 'pos': 0.0, 'compound': -0.5719}
#
# do you think joe #biden would’ve noticed the marine’s hat on the ground #trump stops to pick up marine’s hat on t
# {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.1531}
#
# full story :purple_square::purple_square:#biden #blackexcellence #blackgirlmagic #blackgirlsrock #blackisbeautiful
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# federal court closes the door on biden  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# if trump was putin man wouldn't be logical that #putin would invaded #ukraine under #trump presidency just saying...:smirking_face:#russia #usa
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# via @rawstory: idaho republican ‘just made it so much worse’ with latest comments on white nationalism: gop lawmake
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# bush was an idiot but a controlled idiot and clinton was good.but both are real presidents #trump is to petty
# {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.8316}
#
# @joncoopertweets hard call. #putting and #trump made from the same mold.
# {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.1027}
#
# @rosskneedeep not a doubt in my mind if you ask him he'll tell youhe'll also tell you that he didn't see it as
# {'neg': 0.0, 'neu': 0.912, 'pos': 0.088, 'compound': 0.2755}
#
# remember when @realdonaldtrump still hasn’t released his tax returns  #trump #maga #racistinchief
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @bagdmilksowhat who’s ass did #trump kiss at some shorty resort he owns in #florida.
# {'neg': 0.191, 'neu': 0.656, 'pos': 0.153, 'compound': -0.1779}
#
# icymi: "biden administration fights in court to uphold some trump-era immigration policies" #trump #donaldtrump
# {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.4019}
#
# russia prepared trump to be putin's puppet for decades before he became president  according to former kgb officer.
# {'neg': 0.0, 'neu': 0.899, 'pos': 0.101, 'compound': 0.2263}
#
# another loss. worst batting average ever. #trump #trumpcrimefamily #trumpisalaughingstock
# {'neg': 0.478, 'neu': 0.522, 'pos': 0.0, 'compound': -0.7506}
#
# trump lawyers ask judge to block release of tax returns to congress   #maga #trump2024 #trump
# {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.4404}
#
# @judiciarydems an honor that was not given to any #donthecon appointee i imagine. still seething how quiet that sup
# {'neg': 0.0, 'neu': 0.849, 'pos': 0.151, 'compound': 0.4939}
#
# y did #trump move u.s. troops off the #syrian border  because turkey's pres. erdogan told him he'd take #trump off
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# wtf did i just watch  #nfl  #trump  #brandon  #russia learned a lot from #usa -- welcome to the twilight zonefull
# {'neg': 0.153, 'neu': 0.726, 'pos': 0.121, 'compound': -0.2023}
#
# @joncoopertweets easy  #putin is in power - #trump is in florida.
# {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
#
# @jacy1892 @msnbc us sanctions should include impeaching all russian agent trumps appointed judges. all of them.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# first lady jill biden admits defeat  #maga #trump2024 #trump
# {'neg': 0.246, 'neu': 0.574, 'pos': 0.18, 'compound': -0.2023}
#
# joe biden faces investigation hearing  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @wsj just like a #trump rally.  #putin and trump feed their supporters with lies .
# {'neg': 0.139, 'neu': 0.594, 'pos': 0.267, 'compound': 0.3818}
#
# @joncoopertweets i can't - i need him to vocally condemn the @gop for their support of #trump and i want to hear fr
# {'neg': 0.098, 'neu': 0.752, 'pos': 0.15, 'compound': 0.1027}
#
# do you remember when #trump kept praising #putin and insulting #zelenskyy    let that sink in  and try to understan
# {'neg': 0.135, 'neu': 0.717, 'pos': 0.148, 'compound': 0.0772}
#
# @dtimes17 @260yamaguchi :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aide
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.25}
#
# putin talks about nazis in ukraine the way trump talks about the 2020 election being stolen--all self-serving lies
# {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'compound': -0.4215}
#
# #pbs @newshour just reported #mastercard &amp; #visa are still supporting #russia. wth   i don't want to hear about t
# {'neg': 0.196, 'neu': 0.68, 'pos': 0.123, 'compound': -0.1833}
#
# cnn suffers possibly network-ending loss  #maga #trump2024 #trump
# {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.6597}
#
# #trump #america open your #spiritual eyes_a nation has been stolen by the left #false narratives_better known as li
# {'neg': 0.158, 'neu': 0.842, 'pos': 0.0, 'compound': -0.4939}
#
# #putin doing a #trump rally now #whocouldmakethisup
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# biden’s border situation spins out of control  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# gaslighting is not real you're just crazy#shirt #shirts #biden #trump #gascash #gasprices #usa
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @iwj_sokuho @iwakamiyasumi :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says a
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.25}
#
# looks like #trump
# {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'compound': 0.3612}
#
# @dsa38 @citizenwonk @oregon_resister @lussoangel @hyapatialee @butterflylove_8 @bdk1521 @black2thbone @vegankitty2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# msnbc’s malcolm nance: #trump was on the russians’ radar as ‘early as 1977’ " when it became modern #russia ” cla
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# via soxluva5 : saw this phrase on twitter  so i decided to make a hat in reply to trump's maga hat.  #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @goofytiger2 @swearyharidan if someone supports #putin  then you know they support #trump. there is no difference #trumpputin
# {'neg': 0.103, 'neu': 0.654, 'pos': 0.243, 'compound': 0.4588}
#
# @benniegthompson @repadamschiff @repraskin @replizcheney @repkinzinger investigate bill barr  rudy giuliani
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# fired  arrested cnn producer hit even harder  #maga #trump2024 #trump
# {'neg': 0.456, 'neu': 0.544, 'pos': 0.0, 'compound': -0.7717}
#
# @marshablackburn so &gt;&gt;&gt;&gt; he pretty much fits into your #trump @gop vision for america  you must be a big fan.
# {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.7759}
#
# kyrsten sinema sparks democrat civil war  #maga #trump2024 #trump
# {'neg': 0.328, 'neu': 0.672, 'pos': 0.0, 'compound': -0.5994}
#
# tom cotton just froze out joe biden  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# will republicans please shut up   via @palmerreport #goptherussianpartyoftraitors
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.3182}
#
# so #trump still not allowed back on @twitter despite the conspiracies coming true  #hunterbidenlaptop
# {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215}
#
# supreme court rules on retirement funds  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.5574}
#
# putin  murdoch  trump  qanon  brexit  they're all one &amp; the same thing. russia realised they could do untold damage
# {'neg': 0.151, 'neu': 0.849, 'pos': 0.0, 'compound': -0.4939}
#
# @sorayaresist @crzyfkinworld @ahearncoleen @srh_medco @texy_liz @wipapa5 @rosannaphillip @keysmom1031
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# when is the attorney general of arizona going to rule on all of the election fraud and large-scale election irregul
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.5859}
#
# #putin manages political rally not seen since #nuremberg rally. #trump must be seething with envy. what have in com
# {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.2732}
#
# via @markos: ukraine update: no  media  it's not a 'strategic pause' anymore  russia is just stuck
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.4939}
#
# @vlesions @femme_phememe @glennkirschner2 @claireluvsbearz @kirkacevedo @asweetdiversion @allanmargolin @vegix
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @ronfilipkowski @repmtg realizes she is done in politics and hitched herself to the wrong horse. #trump going to re
# {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'compound': -0.4767}
#
# trump gets flooded by florida crowd  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# . @repmtg: "i have never seen the cdc  saying  'oh you’ve got to get your 2nd polio shot...your 3rd...your 4th.'"
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #trump with brains. #putin
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# critical race theory explained by john oliver  #crt #criticalracetheory #trump #racism #racisminamerica
# {'neg': 0.39, 'neu': 0.61, 'pos': 0.0, 'compound': -0.7506}
#
# desantis gets obama and biden in their hometowns  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# donald trump wants his supporters to carry trump cards  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
#
# pelosi gives shameful order to american olympians  #maga #trump2024 #trump
# {'neg': 0.262, 'neu': 0.738, 'pos': 0.0, 'compound': -0.4939}
#
# i went on a tear against disinformation last night. i got sick of people defending tyrrany with lies. it's time to
# {'neg': 0.243, 'neu': 0.757, 'pos': 0.0, 'compound': -0.7269}
#
# as a moderate  which was/is more entertaining to watch  #trump #biden
# {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4927}
#
# judge sends anti-police ilhan omar reeling  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #putin had the type of rally that he taught #trump to have with #maga. it’s a #putin rally taught to #trump and his
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# how one republican is struggling to get to yes on biden’s big deal  #maga #trump2024 #trump
# {'neg': 0.144, 'neu': 0.718, 'pos': 0.138, 'compound': -0.0258}
#
# when i see references to hunter biden and #arresthunter  i believe it means someone in #trump world is in deep trou
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @jtruss21 @sunflwrgirl2 @katibug817 @beachlifelinda1 @real_chatty_cat @omega7stone @simonjester007 @brittanyintexas
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# @itshammertimeii #mccarthy was told by #pelosi but guess kevin didn’t pass that onto  #theoutsiderone in the pock
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# just in case you were wondering if these people are completely insane and deluded  here you go  #trump #maga #gqp
# {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.4576}
#
# why trump can't resist running in 2024    #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# #stopthesteal (via a coordinated media suppressive scheme) was very real.  the election was stolen by various for
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.4939}
#
# @iamsteveharvey everything said by #republicans  #gop  @gop  #trump #desantis @rondesantisfl @sentedcruz  shall i go on
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# the @nytimes just admitted that it participated in an effort to rig the election for joe biden. #trump #donaldtrump
# {'neg': 0.075, 'neu': 0.854, 'pos': 0.07, 'compound': -0.0258}
#
# mccarthy plans to strip democrats off committees  #maga #trump2024 #trump
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# of course no wars  wall  jobs and a great economy so lets not elect  #trump who got results and instead install
# {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.792}

# %% [markdown]
# # Named Entity Recognition

# %%
nlp = spacy.load('en_core_web_trf')

# %%
for tweet_text in unique_tweets:
    doc = nlp(tweet_text)
    print(tweet_text)
    for ne in doc.ents:
        print('\tNE found: ', ne.start_char, ne.end_char, ne.label_, tweet_text[ne.start_char:ne.end_char])
    print()
# Out:
# this #atheist murderous kgb #dictator quoted #scripture 2 rally his #russian people in support of his #warcrimes. w
#
# i am actually not sure it is such a threat to her political career. if #trump is found guilty of misusing public fu
# 	NE found:  72 77 PERSON trump
#
# @noliewithbtc interesting that #lavrov is such a fan of #trump  @tuckercarlson and @foxnews. #foxnews cameraman p
# 	NE found:  32 38 PERSON lavrov
#
# now...now... be fair. #trump suggest injecting sunshine and bleach.  you have to give him credit for originality on
# 	NE found:  23 28 PERSON trump
#
# navy seals gang up on nancy pelosi  #maga #trump2024 #trump
# 	NE found:  0 4 ORG navy
# 	NE found:  22 34 PERSON nancy pelosi
#
# via @crooksandliars: house progressives give biden a wish list of executive orders  | #trump #gop #republicans
# 	NE found:  45 50 PERSON biden
#
# #january6th and #science and #trump and #america and #democrats and #usa and #freedom and #trumpguilty and
#
# @costavjw @pigriffs @redhorse6531 @phoenixwildish @omega7stone @flblueslayer @calltrixie @agent35512 @katibug957
#
# @ronfilipkowski #trump supporters are
#
# msm is a joke  hunter biden's laptop was and is real joke and :clown_face::clown_face::clown_face::clown_face::clown_face:#laptopfromhell#hunterbidenlaptop
#
# @potus are you still alive  where is #trump
# 	NE found:  38 43 PERSON trump
#
# @fpwellman idiocracy: a disturbingly prophetic look at the future of america – and our era of stupidity
# 	NE found:  69 76 GPE america
#
# mcconnell pulls apart "the big lie"  #maga #trump2024 #trump
# 	NE found:  0 9 PERSON mcconnell
#
# pelosi’s closet swings wide open  #maga #trump2024 #trump
# 	NE found:  0 6 PERSON pelosi
#
# @sjgs_2021 @1joav @maclinx @mary1kathy @rotterdamvvg @enespacio @e_snacks @baconbacon1969 @dmbfangrl76 @koan4uu
#
# @marshablackburn #trump and the @gop already transformed the #scotus by appointments to forward their radical agend
# 	NE found:  32 36 ORG @gop
# 	NE found:  62 68 GPE scotus
#
# #trump was the only reason i was interested in politics. what a man
# 	NE found:  1 6 PERSON trump
#
# joe biden is 'drowning' in his home state  #maga #trump2024 #trump
# 	NE found:  0 9 PERSON joe biden
#
# senator kennedy accuses biden of “illegal” action  #maga #trump2024 #trump
# 	NE found:  8 15 PERSON kennedy
# 	NE found:  24 29 PERSON biden
#
# via @rawstory: scott pruitt seeks trump's endorsement to launch political comeback in oklahoma: report
# 	NE found:  15 27 PERSON scott pruitt
# 	NE found:  86 94 GPE oklahoma
#
# "lame duck pelosi" sabotaged by her own party  #maga #trump2024 #trump
#
# @evankopelson i would like lesley stahl to do a story on trump pushing false rumors about a joe scarborough aid bei
#
# @donniedarkened @conan_esq #god refused to help #trump retake the throne in 2020  so now his #magats turn to #satan.  sounds about right.
# 	NE found:  76 80 DATE 2020
#
# #trump doing 'business' in #scotland - 2011 bulldozing locals to build his golf course.
# 	NE found:  1 6 PERSON trump
# 	NE found:  28 36 GPE scotland
# 	NE found:  39 43 DATE 2011
#
# @tuckercarlson  #trump and all the rest of these nobodies are the lying  hypocritical  a$$bags. let's boot them fro
#
# congress collides with major investigation  #maga #trump2024 #trump
#
# #jesus delivers us from the cares of this world  not the other way around. #putinswar  #trump #letitgo
#
# @soulibird @suziebird4 @vixey_picklejar @sicilianal @cherylbluewave @3sidecarsplz @winners786 @shoathree
#
# same thing @caslernoel has been trying to tell us for years  helloooo    who hasn't been paying attention
#
# #democrats say #putin and #trump are just alike  does anyone think #trump would just give up and walk away or agree
#
# the five fox news 3/18 22 | fox breaking news  @judgejeanine #china @foxnews #ukraine
#
# @taylormadebride @tomthunkitsmind @thegreathouseco @jillfano2 @jewell35_a @mathhatter1 @livetrudi @lsutigers12345
#
# @rosskneedeep yes. and putin has tapes. #trump
# 	NE found:  23 28 PERSON putin
#
# @mazemoore #putinspuppet #clinton #trump debate#tedcruz on #trump
#
# @vantahku @zarleckazpa @bzliberal @donalynette @dreamthesailor @musicistheory @indivisprescott @inderisme
#
# @georgetakei :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kil
# 	NE found:  110 117 ORG kremlin
#
# biden and trump clash head-on  #maga #trump2024 #trump
#
# via @rawstory: watch: ohio gop senate candidates get in each others' faces during heated primary debate
#
# @suziebird4 @soulibird @vixey_picklejar @sicilianal @cherylbluewave @3sidecarsplz @winners786 @shoathree
#
# @msnbc china will do what china wants to do. made in china missiles should never go to putin #impeachtrumpagain
# 	NE found:  26 31 GPE china
# 	NE found:  53 58 GPE china
#
# @duty2warn yes  chris but  as america is still clinging to #democracy power comes from the people. and do you reall
# 	NE found:  16 21 PERSON chris
#
# how to make a conservative angry: lie to them.how to make a liberal angry: tell them the truth.#liberal #biden
#
# @black2thbone @skvl75 @scott_5d @garym27 @vegix @polarsprite @lizmoblubuckeye @klglass2 @steveanders_11 @ps9714
#
# @dtimes17 @yamaatsu2311 :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aide
# 	NE found:  121 128 ORG kremlin
#
# 45th president donald j. trump to hold a rally in michigan #trumprally #michigan #potus45 #trump
# 	NE found:  0 4 ORDINAL 45th
# 	NE found:  15 30 PERSON donald j. trump
# 	NE found:  50 58 GPE michigan
#
# @lecarrigg @60minutes i would like lesley stahl to do a story on trump pushing false rumors about a joe scarborough
# 	NE found:  35 47 PERSON lesley stahl
#
# @johnpavlovitz “the media desperately wants another #trump presidencytheir livelihoods thrive on the sideshowthey
#
# freedom truckers just turned the tables  #maga #trump2024 #trump
#
# virginia republican ag just cleaned house  #maga #trump2024 #trump
# 	NE found:  9 19 NORP republican
#
# #lesliestahl should apologize to #trump she was wrong and should admit it. if she doesn’t her reporting will always
# 	NE found:  1 12 PERSON lesliestahl
# 	NE found:  34 39 PERSON trump
#
# trump asked his ag about legal strategy to overturn election  #maga #trump2024 #trump
#
# another #friday news dump and #hunter in it again. maybe this time. prediction: harris steps down  killary installe
# 	NE found:  9 15 DATE friday
# 	NE found:  30 37 WORK_OF_ART #hunter
# 	NE found:  80 86 PERSON harris
# 	NE found:  99 115 PERSON killary installe
#
# #trump lapdog mark meadows  who never lived where said he did on his voter registration  is worried about voters mo
# 	NE found:  14 26 PERSON mark meadows
#
# the gloves are coming off :boxing_glove:#election2022 is coming up fast and @jfradio is keeping you updated. john says the tur
#
# #trump has a #hearttoheart with #biden #bidenflation #letsgobrandon
#
# #facts49%of americans are  how do i say it nicely  dumbasses. #trump is a mastermind if you are a dumbass
# 	NE found:  63 68 PERSON trump
#
# wow  finally  the bgng of the end  dominoes are falling    the truth always comes to light    #jesusisthetruth
#
# @ek7_prn when #trump was president and "forced" to shut down the economy  i knew something was fishy because that i
#
# federal judge drops green gavel on biden  #maga #trump2024 #trump
# 	NE found:  35 40 PERSON biden
#
# manchin sets the record straight on biden’s bill  #maga #trump2024 #trump
# 	NE found:  0 7 PERSON manchin
# 	NE found:  36 41 PERSON biden
#
# #trump’s ex-chief of staff mark #meadows investigated for #voter #registration #fraud. north carolina authorities a
# 	NE found:  1 6 PERSON trump
# 	NE found:  27 33 PERSON mark #
#
# @dtimes17 :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kill p
# 	NE found:  107 114 ORG kremlin
#
# biden goes head to head with trump and obama  #maga #trump2024 #trump
#
# @livepddave1 lol #trump is not one for apologizing when he intentionally smears innocent citizens with false stor
#
# another trump:U.S._Outlying_Islands: rally april 2 2022 at 7:00 pm. awesome  #trump #trumprally #jesusandtrump
# 	NE found:  43 55 DATE april 2 2022
# 	NE found:  59 66 TIME 7:00 pm
#
# supreme court frontrunner’s closet swings open  #maga #trump2024 #trump
# 	NE found:  0 13 ORG supreme court
#
# @lovemykiaram @repairrestores1 @cynthiaharless1 @rainfery @pandazed @bec2yeg @standforbetter @randomlygeorge @jeber
# supreme court delivers 5-4 decision  #maga #trump2024 #trump
# 	NE found:  23 24 CARDINAL 5
#
# more of my #poetry#bodyparts:  #thetrumpyears: #amazon #poems
#
# @acyn :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kill putin
# 	NE found:  103 110 ORG kremlin
# 	NE found:  137 142 PERSON putin
#
# @joncoopertweets they are both equal both have killed - #ukraine  and #trump killed on #january6thinsurrection
# 	NE found:  71 76 PERSON trump
#
# trump election poll shakes up 2024 race  #maga #trump2024 #trump
# 	NE found:  30 34 DATE 2024
#
# @syd_ayers @donmoyn it's exactly what #putin and other #dictators do. "fake news" is anything unfavorable to him. y
# 	NE found:  39 44 PERSON putin
#
# @niabbot @lbc i’m a scotsman making pasta  listening in houston  texas. so good to have you back. #trumpson will so
# 	NE found:  56 63 GPE houston
# 	NE found:  65 70 GPE texas
# 	NE found:  99 107 PERSON trumpson
#
# @scrantonville @grayzpoo @marisoltorresrs @tcrg2012 @doingjack @silenced777 @lizfortx8 @amymcgrathky @racismloses
#
# her ⁦@cbsnews⁩ #cbsnews ⁦@60minutes⁩ goal was to defeat @gop #trump watch: cbs news reporter falsely told donald
#
# #fbr i follow back those who believe #trump is a #chump#votebluein2022 #arresttrumpnow#joebiden is #decent unlike 45
#
# #conservative #rightwing pundits know they’re presenting a fucked up definition of our #firstamendment #freespeech
# 	NE found:  87 104 LAW #firstamendment #
#
# the only disaster is you  #trump  @tedcruz &amp; your nazi party
#
# @christianwalk1r can u imagine a black kid backing #trump &amp; #gop despite what they do to....black americans. oh wai
# 	NE found:  102 111 NORP americans
#
# icymi: "‘putin’ us on: why dems’ ‘russian disinformation’ claims can’t be taken seriously" #trump #donaldtrump
#
# mass manipulation in #russiaas well as m of #americans believe #trump's #biglie  m of #russian believe the
# 	NE found:  87 94 NORP russian
#
# #trump perfect call
#
# this totally explains why steve harvey met with #trump at trump tower in 2016. i understand completely.
# 	NE found:  26 38 PERSON steve harvey
# 	NE found:  58 69 FAC trump tower
# 	NE found:  73 77 DATE 2016
#
# @gop never forget trump gave us 14% unemployment. @repmtg @mattgaetz @repandybiggsaz  @repboebert @massieforky
# 	NE found:  32 35 PERCENT 14%
#
# @logicfirst1 @antman0528 @logicturn the #trump police in action.
#
# omg  #putin &amp; #trump are of the same cloth: narcissistic sociopathic pathological liars with egos so large they mak
#
# do anyone of you think thatmark ruffalo cares about how many peoplefamilies have had to cut back on other things
#
# aoc’s republican rival just landed lots of blue support  #maga #trump2024 #trump
# 	NE found:  0 3 PERSON aoc
# 	NE found:  6 16 NORP republican
#
# biden impeachment threat goes through the roof  #maga #trump2024 #trump
#
# @dtimes17 @toshihikoogata :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says ai
# 	NE found:  123 130 ORG kremlin
#
# biden plummets in swing state he won in 2020  #maga #trump2024 #trump
# 	NE found:  0 5 PERSON biden
# 	NE found:  40 44 DATE 2020
#
# alex jones on why full send podcast trump interview really got deleted...#alexjones #trump
# 	NE found:  36 41 PERSON trump
#
# @logicfirst1 so did you drink disinfectants  take horse de-wormer or insert uv light in your anus like #trump told
#
# nancy pelosi goes back on her word  #maga #trump2024 #trump
# 	NE found:  0 12 PERSON nancy pelosi
#
# icymi: "ballot bombshells: 20 episodes exposing fraud  illegalities and irregularities in 2020 election" #trump
# 	NE found:  27 29 CARDINAL 20
# 	NE found:  90 94 DATE 2020
#
# so when #trump was president people wanted to build a wall between #usa and #mexico this same people wanne crawl ov
#
# @steveanders_11 @doingjack @dprobbob @dejafuuled @laney2003us @pmurttrump @new_allyo @katibug817 @resisterclaire
#
# alex jones show – 03/18/2022 – economic collapse and nuclear war are only the beginning
#
# @d_jeneration the only problem i see is that free speech gives #foxnews #trump &amp; #gop the freedom to spew #russian
#
# random trump  - #randomtrump #trump #donaldtrump #giphy #gif #gifs
#
# 45th president donald j. trump to hold a rally in michigan #trump #donaldtrump #republican #conservative #trump2024
# 	NE found:  0 4 ORDINAL 45th
# 	NE found:  15 30 PERSON donald j. trump
# 	NE found:  50 58 GPE michigan
#
# @sorayaresist @ritamacmom @texy_liz @srh_medco @rosannaphillip @sugardonaghy @sawmcdargh @wipapa5 @vintageknits
#
# @loudevoyce apologize for what  asking questions given #trump maliciously spread false rumors about private citiz
#
# "adam schiff" continues tolie to voters. this bozo spent4yrs only attacking #trump.#congress #senate #covid#biden #covid
# 	NE found:  1 12 PERSON adam schiff
#
# hunter biden’s laptop anyone  #trump #biden #hunterbiden #ukraine #russia #russiahoax
#
# @novelection2024 no... but #trump's coup on january 6th is the "crime of the century."#trumpisarussianasset
# 	NE found:  44 55 DATE january 6th
#
# @magosaki_ukeru :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would
# 	NE found:  113 120 ORG kremlin
#
# @jackposobiec he’s safe in office now so it’s ok to #stealtheelection. like #clinton won’t face charges for spying
#
# shabbos dinner.  that shiksa melania sat me in between lauren boebert &amp; her husband.when he isn't trying to show
# 	NE found:  55 71 PERSON lauren boebert &
#
# @dtimes17 @tsujimotokiyomi @hamakoto @shirai_satoshi @rqnr_20c :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides tr
#
# pelosi gets served major lawsuit by trump ally  #maga #trump2024 #trump
# 	NE found:  0 6 PERSON pelosi
#
# @reaidonjtrump_ there is no #trump administration. he is in the dustbin of history just spewing out his grievances
# 	NE found:  29 34 PERSON trump
#
# do you think joe #biden would’ve noticed the marine’s hat on the ground #trump stops to pick up marine’s hat on t
# 	NE found:  73 78 PERSON trump
#
# full story :purple_square::purple_square:#biden #blackexcellence #blackgirlmagic #blackgirlsrock #blackisbeautiful
#
# federal court closes the door on biden  #maga #trump2024 #trump
# 	NE found:  33 38 PERSON biden
#
# if trump was putin man wouldn't be logical that #putin would invaded #ukraine under #trump presidency just saying...:smirking_face:#russia #usa
#
# via @rawstory: idaho republican ‘just made it so much worse’ with latest comments on white nationalism: gop lawmake
#
# bush was an idiot but a controlled idiot and clinton was good.but both are real presidents #trump is to petty
# 	NE found:  0 4 PERSON bush
# 	NE found:  45 52 PERSON clinton
# 	NE found:  92 97 PERSON trump
#
# @joncoopertweets hard call. #putting and #trump made from the same mold.
# 	NE found:  42 47 PERSON trump
#
# @rosskneedeep not a doubt in my mind if you ask him he'll tell youhe'll also tell you that he didn't see it as
#
# remember when @realdonaldtrump still hasn’t released his tax returns  #trump #maga #racistinchief
#
# @bagdmilksowhat who’s ass did #trump kiss at some shorty resort he owns in #florida.
# 	NE found:  31 36 PERSON trump
# 	NE found:  76 83 GPE florida
#
# icymi: "biden administration fights in court to uphold some trump-era immigration policies" #trump #donaldtrump
#
# russia prepared trump to be putin's puppet for decades before he became president  according to former kgb officer.
# 	NE found:  0 6 GPE russia
# 	NE found:  28 33 PERSON putin
# 	NE found:  47 54 DATE decades
# 	NE found:  103 106 ORG kgb
#
# another loss. worst batting average ever. #trump #trumpcrimefamily #trumpisalaughingstock
#
# trump lawyers ask judge to block release of tax returns to congress   #maga #trump2024 #trump
#
# @judiciarydems an honor that was not given to any #donthecon appointee i imagine. still seething how quiet that sup
# 	NE found:  51 60 WORK_OF_ART donthecon
#
# y did #trump move u.s. troops off the #syrian border  because turkey's pres. erdogan told him he'd take #trump off
# 	NE found:  18 22 GPE u.s.
# 	NE found:  77 84 PERSON erdogan
#
# wtf did i just watch  #nfl  #trump  #brandon  #russia learned a lot from #usa -- welcome to the twilight zonefull
#
# @joncoopertweets easy  #putin is in power - #trump is in florida.
# 	NE found:  24 29 PERSON putin
# 	NE found:  45 50 PERSON trump
#
# @jacy1892 @msnbc us sanctions should include impeaching all russian agent trumps appointed judges. all of them.
# 	NE found:  17 19 GPE us
# 	NE found:  60 67 NORP russian
# 	NE found:  74 80 PERSON trumps
#
# first lady jill biden admits defeat  #maga #trump2024 #trump
# 	NE found:  11 21 PERSON jill biden
#
# joe biden faces investigation hearing  #maga #trump2024 #trump
# 	NE found:  0 9 PERSON joe biden
#
# @wsj just like a #trump rally.  #putin and trump feed their supporters with lies .
# 	NE found:  33 38 PERSON putin
# 	NE found:  43 48 PERSON trump
# @joncoopertweets i can't - i need him to vocally condemn the @gop for their support of #trump and i want to hear fr
#
# do you remember when #trump kept praising #putin and insulting #zelenskyy    let that sink in  and try to understan
#
# @dtimes17 @260yamaguchi :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aide
# 	NE found:  121 128 ORG kremlin
#
# putin talks about nazis in ukraine the way trump talks about the 2020 election being stolen--all self-serving lies
# 	NE found:  0 5 PERSON putin
# 	NE found:  18 23 NORP nazis
# 	NE found:  27 34 GPE ukraine
# 	NE found:  43 48 PERSON trump
# 	NE found:  65 69 DATE 2020
#
# #pbs @newshour just reported #mastercard &amp; #visa are still supporting #russia. wth   i don't want to hear about t
#
# cnn suffers possibly network-ending loss  #maga #trump2024 #trump
# 	NE found:  0 3 ORG cnn
#
# #trump #america open your #spiritual eyes_a nation has been stolen by the left #false narratives_better known as li
#
# #putin doing a #trump rally now #whocouldmakethisup
# 	NE found:  1 6 PERSON putin
#
# biden’s border situation spins out of control  #maga #trump2024 #trump
#
# gaslighting is not real you're just crazy#shirt #shirts #biden #trump #gascash #gasprices #usa
#
# @iwj_sokuho @iwakamiyasumi :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says a
# 	NE found:  124 131 ORG kremlin
#
# looks like #trump
#
# @dsa38 @citizenwonk @oregon_resister @lussoangel @hyapatialee @butterflylove_8 @bdk1521 @black2thbone @vegankitty2
#
# msnbc’s malcolm nance: #trump was on the russians’ radar as ‘early as 1977’ " when it became modern #russia ” cla
# 	NE found:  0 5 ORG msnbc
# 	NE found:  8 21 PERSON malcolm nance
# 	NE found:  41 49 NORP russians
# 	NE found:  70 74 DATE 1977
# 	NE found:  100 101 GPE #
# 	NE found:  101 107 GPE russia
#
# via soxluva5 : saw this phrase on twitter  so i decided to make a hat in reply to trump's maga hat.  #trump
#
# @goofytiger2 @swearyharidan if someone supports #putin  then you know they support #trump. there is no difference #trumpputin
#
# @benniegthompson @repadamschiff @repraskin @replizcheney @repkinzinger investigate bill barr  rudy giuliani
#
# fired  arrested cnn producer hit even harder  #maga #trump2024 #trump
# 	NE found:  16 19 ORG cnn
#
# @marshablackburn so &gt;&gt;&gt;&gt; he pretty much fits into your #trump @gop vision for america  you must be a big fan.
#
# kyrsten sinema sparks democrat civil war  #maga #trump2024 #trump
# 	NE found:  0 14 PERSON kyrsten sinema
# 	NE found:  22 30 NORP democrat
#
# tom cotton just froze out joe biden  #maga #trump2024 #trump
# 	NE found:  26 35 PERSON joe biden
#
# will republicans please shut up   via @palmerreport #goptherussianpartyoftraitors
# 	NE found:  5 16 NORP republicans
#
# so #trump still not allowed back on @twitter despite the conspiracies coming true  #hunterbidenlaptop
# 	NE found:  4 9 PERSON trump
#
# supreme court rules on retirement funds  #maga #trump2024 #trump
#
# putin  murdoch  trump  qanon  brexit  they're all one &amp; the same thing. russia realised they could do untold damage
# 	NE found:  0 5 PERSON putin
# 	NE found:  76 82 GPE russia
#
# @sorayaresist @crzyfkinworld @ahearncoleen @srh_medco @texy_liz @wipapa5 @rosannaphillip @keysmom1031
#
# when is the attorney general of arizona going to rule on all of the election fraud and large-scale election irregul
#
# #putin manages political rally not seen since #nuremberg rally. #trump must be seething with envy. what have in com
# 	NE found:  1 6 PERSON putin
# 	NE found:  46 62 EVENT #nuremberg rally
# 	NE found:  65 70 PERSON trump
#
# via @markos: ukraine update: no  media  it's not a 'strategic pause' anymore  russia is just stuck
#
# @vlesions @femme_phememe @glennkirschner2 @claireluvsbearz @kirkacevedo @asweetdiversion @allanmargolin @vegix
#
# @ronfilipkowski @repmtg realizes she is done in politics and hitched herself to the wrong horse. #trump going to re
# 	NE found:  98 103 PERSON trump
#
# trump gets flooded by florida crowd  #maga #trump2024 #trump
# 	NE found:  22 29 GPE florida
#
# . @repmtg: "i have never seen the cdc  saying  'oh you’ve got to get your 2nd polio shot...your 3rd...your 4th.'"
# 	NE found:  34 37 ORG cdc
# 	NE found:  74 77 ORDINAL 2nd
# 	NE found:  96 99 ORDINAL 3rd
# 	NE found:  107 110 ORDINAL 4th
#
# #trump with brains. #putin
# 	NE found:  21 26 PERSON putin
#
# critical race theory explained by john oliver  #crt #criticalracetheory #trump #racism #racisminamerica
#
# desantis gets obama and biden in their hometowns  #maga #trump2024 #trump
# 	NE found:  0 8 PERSON desantis
# 	NE found:  14 19 PERSON obama
# 	NE found:  24 29 PERSON biden
#
# donald trump wants his supporters to carry trump cards  #maga #trump2024 #trump
#
# pelosi gives shameful order to american olympians  #maga #trump2024 #trump
#
# i went on a tear against disinformation last night. i got sick of people defending tyrrany with lies. it's time to
# 	NE found:  40 50 TIME last night
# 	NE found:  83 90 PERSON tyrrany
#
# as a moderate  which was/is more entertaining to watch  #trump #biden
#
# judge sends anti-police ilhan omar reeling  #maga #trump2024 #trump
# 	NE found:  24 34 PERSON ilhan omar
#
# #putin had the type of rally that he taught #trump to have with #maga. it’s a #putin rally taught to #trump and his
#
# how one republican is struggling to get to yes on biden’s big deal  #maga #trump2024 #trump
# 	NE found:  50 55 PERSON biden
#
# when i see references to hunter biden and #arresthunter  i believe it means someone in #trump world is in deep trou
# 	NE found:  25 37 PERSON hunter biden
# 	NE found:  43 55 WORK_OF_ART arresthunter
#
# @jtruss21 @sunflwrgirl2 @katibug817 @beachlifelinda1 @real_chatty_cat @omega7stone @simonjester007 @brittanyintexas
#
# @itshammertimeii #mccarthy was told by #pelosi but guess kevin didn’t pass that onto  #theoutsiderone in the pock
#
# just in case you were wondering if these people are completely insane and deluded  here you go  #trump #maga #gqp
#
# why trump can't resist running in 2024    #maga #trump2024 #trump
# 	NE found:  34 38 DATE 2024
#
# #stopthesteal (via a coordinated media suppressive scheme) was very real.  the election was stolen by various for
#
# @iamsteveharvey everything said by #republicans  #gop  @gop  #trump #desantis @rondesantisfl @sentedcruz  shall i go on
# 	NE found:  36 47 NORP republicans
#
# the @nytimes just admitted that it participated in an effort to rig the election for joe biden. #trump #donaldtrump
# 	NE found:  4 12 ORG @nytimes
# 	NE found:  85 94 PERSON joe biden
#
# mccarthy plans to strip democrats off committees  #maga #trump2024 #trump
# 	NE found:  0 8 PERSON mccarthy
#
# of course no wars  wall  jobs and a great economy so lets not elect  #trump who got results and instead install

# %% [markdown]
# # Named Entity Linking

# %%
nlp = spacy.load("en_core_web_md")

#add to pipeline
nlp.add_pipe('entityLinker', last=True)

# %%
for tweet_text in unique_tweets:
    try:
        doc = nlp(tweet_text)
        print(tweet_text)
        all_linked_entities = doc._.linkedEntities
        for linked_entity in all_linked_entities:
            print(linked_entity.get_url() + ' ' + linked_entity.pretty_string(True))
        print()
    except:
        pass
# Out:
# this #atheist murderous kgb #dictator quoted #scripture 2 rally his #russian people in support of his #warcrimes. w
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q80919 kgb  => KGB <main security agency for the Soviet Union>
# https://www.wikidata.org/wiki/Q175331 rally  => demonstration <collective action by people in favor of a cause>
# https://www.wikidata.org/wiki/Q179461 scripture  => religious text <type of creative work>
# https://www.wikidata.org/wiki/Q49542 russian,people  => Russians <East Slavic ethnic group, regardless of country of citizenship>
# https://www.wikidata.org/wiki/Q1136376 support  => support <part of the domain of a mathematical function>
#
# i am actually not sure it is such a threat to her political career. if #trump is found guilty of misusing public fu
# https://www.wikidata.org/wiki/Q707125 threat  => threat <one person's statement that they intend to harm another, or another's property>
# https://www.wikidata.org/wiki/Q282049 career  => career <>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q40709 fu  => ふ <character of the Japanese alphabet>
#
# @noliewithbtc interesting that #lavrov is such a fan of #trump  @tuckercarlson and @foxnews. #foxnews cameraman p
# https://www.wikidata.org/wiki/Q1208175 cameraman  => camera operator <professional operator of a film or video camera>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# now...now... be fair. #trump suggest injecting sunshine and bleach.  you have to give him credit for originality on
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q478212 sunshine  => Sunshine <2007 British-American science fiction film directed by Danny Boyle>
# https://www.wikidata.org/wiki/Q407204 bleach  => sodium hypochlorite <chemical compound>
# https://www.wikidata.org/wiki/Q182076 credit  => credit <loan>
# https://www.wikidata.org/wiki/Q2914681 originality  => originality <aspect of created or invented works as being new or novel, and thus distinguishable from reproductions, clones, forgeries, or derivative works>
#
# navy seals gang up on nancy pelosi  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q178033 navy,seals  => United States Navy SEALs <United States Navy’s primary special operations force>
# https://www.wikidata.org/wiki/Q40898 nancy  => Nancy <city in Meurthe-et-Moselle, France>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# via @crooksandliars: house progressives give biden a wish list of executive orders  | #trump #gop #republicans
# https://www.wikidata.org/wiki/Q20502 house  => house music <genre of dance music that originated in the American city of Chicago in the early 1980s>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q27948 list  => list <abstract data type used in computer science>
# https://www.wikidata.org/wiki/Q1338798 executive,orders  => United States executive order <instruction to Federal government issued by the President of the United States>
# https://www.wikidata.org/wiki/Q1132051 |  => vertical bar <character>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #january6th and #science and #trump and #america and #democrats and #usa and #freedom and #trumpguilty and
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q336 science  => science <study and knowledge of the natural world; the natural and social sciences>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q30 america  => United States of America <federal republic in North America>
# https://www.wikidata.org/wiki/Q29552 democrats  => Democratic Party <political party in the United States>
# https://www.wikidata.org/wiki/Q114147 usa  => Usa <city in Ōita Prefecture, Japan>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @costavjw @pigriffs @redhorse6531 @phoenixwildish @omega7stone @flblueslayer @calltrixie @agent35512 @katibug957
#
# @ronfilipkowski #trump supporters are
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# msm is a joke  hunter biden's laptop was and is real joke and :clown_face::clown_face::clown_face::clown_face::clown_face:#laptopfromhell#hunterbidenlaptop
# https://www.wikidata.org/wiki/Q853451 msm  => men who have sex with men <sexual behavior>
# https://www.wikidata.org/wiki/Q3962 laptop  => laptop <personal computer for mobile use>
# https://www.wikidata.org/wiki/Q131138 joke  => joke <something spoken, written, or done with humorous intention>
# https://www.wikidata.org/wiki/Q5944264 hunter,biden  => Hunter Biden <son of former Vice President of the United States Joe Biden>
# https://www.wikidata.org/wiki/Q131138 joke  => joke <something spoken, written, or done with humorous intention>
#
# @potus are you still alive  where is #trump
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
#
# @fpwellman idiocracy: a disturbingly prophetic look at the future of america – and our era of stupidity
# https://www.wikidata.org/wiki/Q1347609 idiocracy  => Idiocracy <2006 film by Mike Judge>
# https://www.wikidata.org/wiki/Q2740768 look  => Look <magazine published in Des Moines, Iowa>
# https://www.wikidata.org/wiki/Q344 future  => future <time which has yet to occur>
# https://www.wikidata.org/wiki/Q30 america  => United States of America <federal republic in North America>
# https://www.wikidata.org/wiki/Q6428674 era  => era <an approximation of spatio-temporal bounds marked by cultural or natural phenomena>
# https://www.wikidata.org/wiki/Q795 stupidity  => stupidity <state of lacking intelligence>
#
# mcconnell pulls apart "the big lie"  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q13553908 mcconnell  => McConnell <family name>
# https://www.wikidata.org/wiki/Q2083614 big,lie  => big lie <Saying a lie and stay strong in the statement.>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# pelosi’s closet swings wide open  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q203775 swings  => swing music <genre of jazz music>
# https://www.wikidata.org/wiki/Q47544271 pelosi  => Pelosi <family name>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @sjgs_2021 @1joav @maclinx @mary1kathy @rotterdamvvg @enespacio @e_snacks @baconbacon1969 @dmbfangrl76 @koan4uu
#
# @marshablackburn #trump and the @gop already transformed the #scotus by appointments to forward their radical agend
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q778505 appointments  => The Appointment <1969 film by Sidney Lumet>
#
# #trump was the only reason i was interested in politics. what a man
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q178354 reason  => reason <capacity for consciously making sense of things>
# https://www.wikidata.org/wiki/Q7163 politics  => politics <practice and theory of influencing other people, as in government>
# https://www.wikidata.org/wiki/Q8441 man  => man <male adult human>
#
# joe biden is 'drowning' in his home state  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q6279 joe,biden  => Joe Biden <47th Vice President of the United States (in office from 2009 to 2017)>
# https://www.wikidata.org/wiki/Q54958432 home,state  => Home State <album>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# senator kennedy accuses biden of “illegal” action  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q9696 kennedy  => John F. Kennedy <35th President of the United States of America>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q188473 action  => action film <film genre>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# via @rawstory: scott pruitt seeks trump's endorsement to launch political comeback in oklahoma: report
# https://www.wikidata.org/wiki/Q4354391 scott  => Amanda Lindhout <journalist and humanitarian>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q1113939 comeback  => comeback <return of a person of public interest (artist, politician) after a long-term hiatus>
# https://www.wikidata.org/wiki/Q1649 oklahoma  => Oklahoma <state of the United States of America>
#
# "lame duck pelosi" sabotaged by her own party  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q3736439 duck  => duck <common name for many species in the bird family Anatidae>
# https://www.wikidata.org/wiki/Q7278 party  => political party <organization that seeks to influence government policy and actions>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @evankopelson i would like lesley stahl to do a story on trump pushing false rumors about a joe scarborough aid bei
# https://www.wikidata.org/wiki/Q451695 lesley,stahl  => Lesley Stahl <American journalist>
# https://www.wikidata.org/wiki/Q1318295 story  => narrative <account that presents connected events>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q878352 rumors  => rumor <unverified account or explanation>
# https://www.wikidata.org/wiki/Q2827815 aid  => aid <voluntary transfer of resources from one country to another>
#
# @donniedarkened @conan_esq #god refused to help #trump retake the throne in 2020  so now his #magats turn to #satan.  sounds about right.
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q178885 god  => deity <natural or supernatural god or goddess, divine being>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q189233 throne  => throne <seat of state of a potentate or dignitary>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q35230 satan  => Satan <Christian devil>
#
# #trump doing 'business' in #scotland - 2011 bulldozing locals to build his golf course.
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q4830453 business  => business <organization involved in commercial, industrial, or professional activity>
# https://www.wikidata.org/wiki/Q22 scotland  => Scotland <country in Northwest Europe, part of the United Kingdom>
# https://www.wikidata.org/wiki/Q11851202 locals  => Local union <locally based trade union organization which forms part of a larger union>
# https://www.wikidata.org/wiki/Q1048525 golf,course  => golf course <series of holes designed for the game of golf>
#
# @tuckercarlson  #trump and all the rest of these nobodies are the lying  hypocritical  a$$bags. let's boot them fro
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q879844 rest  => rest <interval of silence in a piece of music, marked by a rest symbol indicating the length of the pause (each rest symbol and name corresponds with a particular note value for length, indicating how long the silence should last)>
# https://www.wikidata.org/wiki/Q30600523 nobodies  => Nobodies <television series>
#
# congress collides with major investigation  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q2495862 congress  => congress <formal meeting of the representatives of different nations, independent organizations (such as trade unions), or groups>
# https://www.wikidata.org/wiki/Q21004260 investigation  => inquiry <process that has the aim of augmenting knowledge, resolving doubt, or solving a problem>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #jesus delivers us from the cares of this world  not the other way around. #putinswar  #trump #letitgo
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q302 jesus  => Jesus Christ <Jewish preacher and religious leader, central figure of Christianity>
# https://www.wikidata.org/wiki/Q3658527 cares  => Care <band>
# https://www.wikidata.org/wiki/Q16502 world  => world <planet Earth and all life upon it, including human civilization>
# https://www.wikidata.org/wiki/Q17641254 way  => Andrew John Henry Way <American portrait and still life painter>
# https://www.wikidata.org/wiki/Q3236915 letitgo  => Letitgo <1994 single by Prince>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @soulibird @suziebird4 @vixey_picklejar @sicilianal @cherylbluewave @3sidecarsplz @winners786 @shoathree
#
# same thing @caslernoel has been trying to tell us for years  helloooo    who hasn't been paying attention
# https://www.wikidata.org/wiki/Q387834 thing  => thing <type of governing assembly>
# https://www.wikidata.org/wiki/Q577 years  => year <orbital period of the Earth around the Sun>
# https://www.wikidata.org/wiki/Q6501338 attention  => attention <behavioral and cognitive process of selectively concentrating on a discrete aspect of information, whether deemed subjective or objective, while ignoring other perceivable information>
#
# #democrats say #putin and #trump are just alike  does anyone think #trump would just give up and walk away or agree
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q29552 democrats  => Democratic Party <political party in the United States>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# the five fox news 3/18 22 | fox breaking news  @judgejeanine #china @foxnews #ukraine
# https://www.wikidata.org/wiki/Q186068 fox,news  => Fox News <American pay television news channel>
# https://www.wikidata.org/wiki/Q1304122 breaking,news  => breaking news <current issue that has to be reported>
# https://www.wikidata.org/wiki/Q148 china  => People's Republic of China <state in East Asia>
#
# @taylormadebride @tomthunkitsmind @thegreathouseco @jillfano2 @jewell35_a @mathhatter1 @livetrudi @lsutigers12345
#
# @rosskneedeep yes. and putin has tapes. #trump
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
# https://www.wikidata.org/wiki/Q149757 tapes  => Compact Audio Cassette <magnetic tape recording format for audio recording and playback>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @mazemoore #putinspuppet #clinton #trump debate#tedcruz on #trump
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q1124 clinton  => Bill Clinton <American lawyer, politician and 42nd President of the United States>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# @vantahku @zarleckazpa @bzliberal @donalynette @dreamthesailor @musicistheory @indivisprescott @inderisme
#
# @georgetakei :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kil
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
# https://www.wikidata.org/wiki/Q193891 vet  => veteran <person who has served in the armed forces>
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
#
# biden and trump clash head-on  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q1162163 head  => director <person who leads a particular area of a company or organisation>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# via @rawstory: watch: ohio gop senate candidates get in each others' faces during heated primary debate
# https://www.wikidata.org/wiki/Q1397 ohio  => Ohio <state of the United States of America>
# https://www.wikidata.org/wiki/Q618536 candidates  => candidate <prospective recipient of an award or honor, or a person seeking or being considered for some kind of position>
# https://www.wikidata.org/wiki/Q37017 faces  => face <part of the body at the front of the head>
# https://www.wikidata.org/wiki/Q1433373 others  => other <philosophical, psychological and anthropological concept that refers to the opposite of one's own identity>
# https://www.wikidata.org/wiki/Q179875 debate  => debate <argument with formal rules, is usually used to prepare a substantive vote>
#
# @suziebird4 @soulibird @vixey_picklejar @sicilianal @cherylbluewave @3sidecarsplz @winners786 @shoathree
#
# @msnbc china will do what china wants to do. made in china missiles should never go to putin #impeachtrumpagain
# https://www.wikidata.org/wiki/Q148 china  => People's Republic of China <state in East Asia>
# https://www.wikidata.org/wiki/Q148 china  => People's Republic of China <state in East Asia>
# https://www.wikidata.org/wiki/Q974850 missiles  => missile <self-propelled guided weapon system>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
#
# @duty2warn yes  chris but  as america is still clinging to #democracy power comes from the people. and do you reall
# https://www.wikidata.org/wiki/Q339346 chris  => Chris <unisex given name>
# https://www.wikidata.org/wiki/Q30 america  => United States of America <federal republic in North America>
# https://www.wikidata.org/wiki/Q7174 democracy  => democracy <system of government in which citizens vote directly in or elect representatives to form a governing body, sometimes called "rule of the majority">
# https://www.wikidata.org/wiki/Q5 people  => human <common name of Homo sapiens, unique extant species of the genus Homo>
#
# how to make a conservative angry: lie to them.how to make a liberal angry: tell them the truth.#liberal #biden
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
#
# @black2thbone @skvl75 @scott_5d @garym27 @vegix @polarsprite @lizmoblubuckeye @klglass2 @steveanders_11 @ps9714
#
# @dtimes17 @yamaatsu2311 :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aide
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
# https://www.wikidata.org/wiki/Q193891 vet  => veteran <person who has served in the armed forces>
# https://www.wikidata.org/wiki/Q12252907 aide  => Aide <Basque numenistic deity of the air>
#
# 45th president donald j. trump to hold a rally in michigan #trumprally #michigan #potus45 #trump
# https://www.wikidata.org/wiki/Q22686 president,donald,j.,trump  => Donald Trump <45th and current president of the United States>
# https://www.wikidata.org/wiki/Q175331 rally  => demonstration <collective action by people in favor of a cause>
# https://www.wikidata.org/wiki/Q1166 michigan  => Michigan <state of the United States of America>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @lecarrigg @60minutes i would like lesley stahl to do a story on trump pushing false rumors about a joe scarborough
# https://www.wikidata.org/wiki/Q451695 lesley,stahl  => Lesley Stahl <American journalist>
# https://www.wikidata.org/wiki/Q1318295 story  => narrative <account that presents connected events>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q878352 rumors  => rumor <unverified account or explanation>
# https://www.wikidata.org/wiki/Q1280288 joe,scarborough  => Joe Scarborough <American cable news and talk radio host, lawyer, author, and former politician>
#
# @johnpavlovitz “the media desperately wants another #trump presidencytheir livelihoods thrive on the sideshowthey
# https://www.wikidata.org/wiki/Q1740954 media  => tunica media <middle layer of blood vessel>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
#
# freedom truckers just turned the tables  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q2979 freedom  => liberty <ability of individuals to have agency>
# https://www.wikidata.org/wiki/Q496946 tables  => table <arrangement of data in rows and columns>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# virginia republican ag just cleaned house  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q20502 house  => house music <genre of dance music that originated in the American city of Chicago in the early 1980s>
# https://www.wikidata.org/wiki/Q781 ag  => Antigua and Barbuda <country in the Caribbean>
# https://www.wikidata.org/wiki/Q1370 virginia  => Virginia <state of the United States of America>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #lesliestahl should apologize to #trump she was wrong and should admit it. if she doesn’t her reporting will always
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q11030 reporting  => journalism <investigation and reporting of events, issues and trends to a broad audience>
#
# trump asked his ag about legal strategy to overturn election  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q781 ag  => Antigua and Barbuda <country in the Caribbean>
# https://www.wikidata.org/wiki/Q185451 strategy  => strategy <high-level plan to achieve objectives in uncertain conditions>
# https://www.wikidata.org/wiki/Q40231 election  => election <process by which a population chooses an individual to hold public office>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# another #friday news dump and #hunter in it again. maybe this time. prediction: harris steps down  killary installe
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q11471 time  => time <dimension in which events can be ordered from the past through the present into the future>
# https://www.wikidata.org/wiki/Q748250 prediction  => prediction <statement about an uncertain event>
# https://www.wikidata.org/wiki/Q3106117 harris  => Lawren Harris <Canadian painter>
#
# #trump lapdog mark meadows  who never lived where said he did on his voter registration  is worried about voters mo
# https://www.wikidata.org/wiki/Q38499 lapdog  => lapdog <dog intended as a human companion>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q1980404 voter,registration  => voter registration <requirement that a person register before they will be permitted to vote, or the process of registering to vote>
# https://www.wikidata.org/wiki/Q2386616 voters  => eligible voter <person entitled to vote in an election>
#
# the gloves are coming off :boxing_glove:#election2022 is coming up fast and @jfradio is keeping you updated. john says the tur
# https://www.wikidata.org/wiki/Q169031 gloves  => glove <covering worn on the hand>
# https://www.wikidata.org/wiki/Q129308 john  => John <King of England>
#
# #trump has a #hearttoheart with #biden #bidenflation #letsgobrandon
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #facts49%of americans are  how do i say it nicely  dumbasses. #trump is a mastermind if you are a dumbass
# https://www.wikidata.org/wiki/Q554082 americans  => Hugo Anton Fisher <American painter>
# https://www.wikidata.org/wiki/Q193607 dumbasses  => idiot <person of low intelligence>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q17286 mastermind  => Mastermind <board game>
# https://www.wikidata.org/wiki/Q193607 dumbass  => idiot <person of low intelligence>
#
# wow  finally  the bgng of the end  dominoes are falling    the truth always comes to light    #jesusisthetruth
# https://www.wikidata.org/wiki/Q5375780 end  => end <in American and Canadian football, a player who lines up at either end of the line of scrimmage, usually beside the tackles>
# https://www.wikidata.org/wiki/Q32907 dominoes  => dominoes <Chinese game played with rectangular tiles>
# https://www.wikidata.org/wiki/Q7949 truth  => truth <what is in accord with fact or reality>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @ek7_prn when #trump was president and "forced" to shut down the economy  i knew something was fishy because that i
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q1255921 president  => president <non-political leader of an organization, company, community, club, trade union, university or other group>
# https://www.wikidata.org/wiki/Q159810 economy  => economy <an area of the production, distribution and trade, as well as consumption of goods and services by different agents.>
#
# federal judge drops green gavel on biden  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q9298846 federal,judge  => federal judge <>
# https://www.wikidata.org/wiki/Q2625659 gavel  => Gavel <>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# manchin sets the record straight on biden’s bill  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q25113935 manchin  => Manchin <family name>
# https://www.wikidata.org/wiki/Q178588 record  => gramophone record <disc-shaped vinyl analog sound storage medium>
# https://www.wikidata.org/wiki/Q190581 bill  => invoice <commercial document issued by a seller to a buyer, relating to a sale transaction and indicating the products, quantities, and agreed prices for products or services the seller has provided the buyer>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #trump’s ex-chief of staff mark #meadows investigated for #voter #registration #fraud. north carolina authorities a
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q9968 ex  => X <letter of the Latin alphabet>
# https://www.wikidata.org/wiki/Q180309 -  => hyphen <punctuation mark used to join words>
# https://www.wikidata.org/wiki/Q6813432 staff  => staff <group of military officers that are responsible for the needs of a unit>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q28813 fraud  => fraud <intentional deception made for personal gain or to damage another individual>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q36524 authorities  => authority control <unique headings used for bibliographic information>
#
# @dtimes17 :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kill p
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
# https://www.wikidata.org/wiki/Q193891 vet  => veteran <person who has served in the armed forces>
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
#
# biden goes head to head with trump and obama  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q1162163 head  => director <person who leads a particular area of a company or organisation>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q76 obama  => Barack Obama <44th president of the United States>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @livepddave1 lol #trump is not one for apologizing when he intentionally smears innocent citizens with false stor
# https://www.wikidata.org/wiki/Q2134 lol  => LOL <Internet slang>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q2472587 citizens  => people <plurality of persons considered as a whole, from a government perspective>
# https://www.wikidata.org/wiki/Q6191471 stor  => Stor <Swedish Hip-hop musician>
#
# another trump:U.S._Outlying_Islands: rally april 2 2022 at 7:00 pm. awesome  #trump #trumprally #jesusandtrump
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q175331 rally  => demonstration <collective action by people in favor of a cause>
# https://www.wikidata.org/wiki/Q118 april  => April <fourth month in the Julian and Gregorian calendars>
# https://www.wikidata.org/wiki/Q34617 pm  => Saint Pierre and Miquelon <self-governing territorial overseas collectivity of France>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# supreme court frontrunner’s closet swings open  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q203775 swings  => swing music <genre of jazz music>
# https://www.wikidata.org/wiki/Q41487 court  => court <judicial institution with the authority to resolve legal disputes>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @lovemykiaram @repairrestores1 @cynthiaharless1 @rainfery @pandazed @bec2yeg @standforbetter @randomlygeorge @jeber
# supreme court delivers 5-4 decision  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q190752 supreme,court  => supreme court <highest court in a jurisdiction>
# https://www.wikidata.org/wiki/Q732833 decision  => decision <legislative act of the European Union>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# more of my #poetry#bodyparts:  #thetrumpyears: #amazon #poems
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q3884 amazon  => Amazon <American electronic commerce and cloud computing company>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @acyn :Ukraine::Ukraine::Ukraine::Ukraine:#putin may be "paranoid" about his aides trying to oust him. kremlin vet says aides would kill putin
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
# https://www.wikidata.org/wiki/Q193891 vet  => veteran <person who has served in the armed forces>
# https://www.wikidata.org/wiki/Q12252907 aides  => Aide <Basque numenistic deity of the air>
#
# @joncoopertweets they are both equal both have killed - #ukraine  and #trump killed on #january6thinsurrection
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# trump election poll shakes up 2024 race  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q40231 election  => election <process by which a population chooses an individual to hold public office>
# https://www.wikidata.org/wiki/Q7129609 race  => Caucasian <grouping of human beings>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @syd_ayers @donmoyn it's exactly what #putin and other #dictators do. "fake news" is anything unfavorable to him. y
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q28549308 fake,news  => fake news <hoax or deliberate spread of misinformation>
# https://www.wikidata.org/wiki/Q9973 y  => Y <letter of the Latin alphabet>
#
# @niabbot @lbc i’m a scotsman making pasta  listening in houston  texas. so good to have you back. #trumpson will so
# https://www.wikidata.org/wiki/Q178 pasta  => pasta <Italian food made from flour, eggs and water and shaped in different forms, usually cooked and served with a sauce>
# https://www.wikidata.org/wiki/Q16555 houston  => Houston <county seat of Harris County, Texas; fourth largest city in the United States by population>
# https://www.wikidata.org/wiki/Q1439 texas  => Texas <state of the United States of America>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# @scrantonville @grayzpoo @marisoltorresrs @tcrg2012 @doingjack @silenced777 @lizfortx8 @amymcgrathky @racismloses
#
# her ⁦@cbsnews⁩ #cbsnews ⁦@60minutes⁩ goal was to defeat @gop #trump watch: cbs news reporter falsely told donald
# https://www.wikidata.org/wiki/Q4503831 goal  => goal <desired result or outcome>
# https://www.wikidata.org/wiki/Q178794 watch  => watch <personal timepiece>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q7753923 news,reporter  => The News Reporter <Local newspaper in Whiteville, North Carolina; won Pulitzer prize in 1953.>
#
# #fbr i follow back those who believe #trump is a #chump#votebluein2022 #arresttrumpnow#joebiden is #decent unlike 45
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #conservative #rightwing pundits know they’re presenting a fucked up definition of our #firstamendment #freespeech
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q101072 definition  => definition <statement that explains the meaning of a term>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# the only disaster is you  #trump  @tedcruz &amp; your nazi party
# https://www.wikidata.org/wiki/Q3839081 disaster  => disaster <hazard resulting in an event causing significant physical damage, destruction or death>
# https://www.wikidata.org/wiki/Q7320 nazi,party  => Nazi Party <political party in Germany between 1920 and 1945>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q25272 amp  => ampere <SI base unit of electric current>
#
# @christianwalk1r can u imagine a black kid backing #trump &amp; #gop despite what they do to....black americans. oh wai
# https://www.wikidata.org/wiki/Q7569 kid  => child <human between the stages of birth and puberty>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q25272 amp  => ampere <SI base unit of electric current>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q49085 black,americans  => African Americans <racial or ethnic group in the United States with African ancestry>
# https://www.wikidata.org/wiki/Q1614911 wai  => Thai greeting <>
#
# icymi: "‘putin’ us on: why dems’ ‘russian disinformation’ claims can’t be taken seriously" #trump #donaldtrump
# https://www.wikidata.org/wiki/Q836925 claims  => complaint <Legal document, the filing of which initiates a lawsuit>
# https://www.wikidata.org/wiki/Q189656 disinformation  => disinformation <false information spread deliberately to deceive>
# https://www.wikidata.org/wiki/Q29552 dems  => Democratic Party <political party in the United States>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# mass manipulation in #russiaas well as m of #americans believe #trump's #biglie  m of #russian believe the
# https://www.wikidata.org/wiki/Q39057704 mass,manipulation  => Mass Manipulation <2017 album>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q43483 well  => well <excavation or structure created in the ground to access groundwater>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q554082 americans  => Hugo Anton Fisher <American painter>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q7737 russian  => Russian <East Slavic language>
# https://www.wikidata.org/wiki/Q11573 m  => metre <SI unit of length>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #trump perfect call
# https://www.wikidata.org/wiki/Q353659 call  => call sign <unique designation for a transmitting station>
#
# this totally explains why steve harvey met with #trump at trump tower in 2016. i understand completely.
# https://www.wikidata.org/wiki/Q2347009 steve,harvey  => Steve Harvey <American stand-up comedian and television host>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q868772 trump,tower  => Trump Tower <skyscraper in Midtown Manhattan, New York City>
#
# @gop never forget trump gave us 14% unemployment. @repmtg @mattgaetz @repandybiggsaz  @repboebert @massieforky
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q41171 unemployment  => unemployment <when people are without work and actively seeking work>
#
# @logicfirst1 @antman0528 @logicturn the #trump police in action.
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q35535 police  => police <constituted body of persons empowered by the state to enforce the law>
# https://www.wikidata.org/wiki/Q188473 action  => action film <film genre>
#
# omg  #putin &amp; #trump are of the same cloth: narcissistic sociopathic pathological liars with egos so large they mak
# https://www.wikidata.org/wiki/Q252733 omg  => Object Management Group <technology standards consortium>
# https://www.wikidata.org/wiki/Q67020368 liars  => Liar <2019 single by Camila Cabello>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
# https://www.wikidata.org/wiki/Q25272 amp  => ampere <SI base unit of electric current>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q15040717 cloth  => The Cloth <2013 film>
# https://www.wikidata.org/wiki/Q149307 egos  => Ego <2009 single by Beyoncé>
#
# do anyone of you think thatmark ruffalo cares about how many peoplefamilies have had to cut back on other things
# https://www.wikidata.org/wiki/Q387834 things  => thing <type of governing assembly>
#
# aoc’s republican rival just landed lots of blue support  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q3823905 rival  => The Rival <1955 film by Anton Giulio Majano>
# https://www.wikidata.org/wiki/Q55223040 aoc  => Alexandria Ocasio-Cortez <American politician>
# https://www.wikidata.org/wiki/Q6501349 lots  => parking lot <cleared area that is intended for parking vehicles>
# https://www.wikidata.org/wiki/Q1136376 support  => support <part of the domain of a mathematical function>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# biden impeachment threat goes through the roof  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q480498 impeachment  => impeachment <formal process in which an official is accused of unlawful activity>
# https://www.wikidata.org/wiki/Q83180 roof  => roof <top covering of a building>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# ...
# https://www.wikidata.org/wiki/Q179651 scale  => scale <ordered arrangement of musical tones with tone or halftone differences>
#
# #putin manages political rally not seen since #nuremberg rally. #trump must be seething with envy. what have in com
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
# https://www.wikidata.org/wiki/Q175331 rally  => demonstration <collective action by people in favor of a cause>
# https://www.wikidata.org/wiki/Q160225 nuremberg,rally  => Nuremberg Rally <annual rally of the Nazi Party in Nurenberg, Germany>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q188739 envy  => envy <resentful emotion that "occurs when a person lacks another's (perceived) superior quality, achievement or possession and wishes that the other lacked it>
#
# via @markos: ukraine update: no  media  it's not a 'strategic pause' anymore  russia is just stuck
# https://www.wikidata.org/wiki/Q30919232 update  => Update <album by Yandel>
# https://www.wikidata.org/wiki/Q1740954 media  => tunica media <middle layer of blood vessel>
# https://www.wikidata.org/wiki/Q830328 pause  => fermata <symbol of musical notation indicating that the note should be prolonged beyond its normal duration or note value would indicate>
# https://www.wikidata.org/wiki/Q159 russia  => Russia <transcontinental country in Eastern Europe and Northern Asia>
#
# @vlesions @femme_phememe @glennkirschner2 @claireluvsbearz @kirkacevedo @asweetdiversion @allanmargolin @vegix
#
# @ronfilipkowski @repmtg realizes she is done in politics and hitched herself to the wrong horse. #trump going to re
# https://www.wikidata.org/wiki/Q7163 politics  => politics <practice and theory of influencing other people, as in government>
# https://www.wikidata.org/wiki/Q726 horse  => horse <domesticated (work) animal>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# trump gets flooded by florida crowd  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q13430821 crowd  => crowd <large group of people that are gathered or considered together>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# . @repmtg: "i have never seen the cdc  saying  'oh you’ve got to get your 2nd polio shot...your 3rd...your 4th.'"
# https://www.wikidata.org/wiki/Q1143522 cdc  => Cult of the Dead Cow <American hacker organization>
# https://www.wikidata.org/wiki/Q12195 polio  => poliomyelitis <Human disease>
# https://www.wikidata.org/wiki/Q3278442 3rd  => 3rd <1996 extended play by The Rasmus>
#
# #trump with brains. #putin
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q1073 brains  => brain <organ that serves as the center of the nervous system in all vertebrate and most invertebrate animals>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
#
# critical race theory explained by john oliver  #crt #criticalracetheory #trump #racism #racisminamerica
# https://www.wikidata.org/wiki/Q5186753 critical,race,theory  => Critical race theory <theory analyzing the role of law in the maintenance of white supremacy>
# https://www.wikidata.org/wiki/Q129308 john  => John <King of England>
# https://www.wikidata.org/wiki/Q1539601 oliver  => Oliver <chimpanzee>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q8461 racism  => racism <belief in the superiority of one race over another>
#
# desantis gets obama and biden in their hometowns  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q56244080 desantis  => DeSantis <family name>
# https://www.wikidata.org/wiki/Q76 obama  => Barack Obama <44th president of the United States>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q387760 hometowns  => Hometown <City in Cook county, Illinois, United States>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# donald trump wants his supporters to carry trump cards  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q22686 donald,trump  => Donald Trump <45th and current president of the United States>
# https://www.wikidata.org/wiki/Q10940 supporters  => jockstrap <undergarment originally designed for supporting the male genitalia>
# https://www.wikidata.org/wiki/Q727407 trump,cards  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# pelosi gives shameful order to american olympians  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q47544271 pelosi  => Pelosi <family name>
# https://www.wikidata.org/wiki/Q1473607 order  => degree of a polynomial <highest power of the variables occurring in a monomial in a given polynomial>
# https://www.wikidata.org/wiki/Q7089016 olympians  => Olympians <fictional comic book species>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# i went on a tear against disinformation last night. i got sick of people defending tyrrany with lies. it's time to
# https://www.wikidata.org/wiki/Q76469 tear  => tear <secretion that cleans and lubricates the eyes>
# https://www.wikidata.org/wiki/Q189656 disinformation  => disinformation <false information spread deliberately to deceive>
# https://www.wikidata.org/wiki/Q1783318 last,night  => Last Night <2010 film by Massy Tadjedin>
# https://www.wikidata.org/wiki/Q5 people  => human <common name of Homo sapiens, unique extant species of the genus Homo>
# https://www.wikidata.org/wiki/Q4925193 lies  => lie <intentionally false statement to a person or group made by another person or group who knows it is not wholly the truth>
# https://www.wikidata.org/wiki/Q11471 time  => time <dimension in which events can be ordered from the past through the present into the future>
#
# as a moderate  which was/is more entertaining to watch  #trump #biden
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# judge sends anti-police ilhan omar reeling  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q16533 judge  => judge <official who presides over court proceedings>
# https://www.wikidata.org/wiki/Q26436159 ilhan,omar  => Ilhan Omar <American politician from Minnesota>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# #putin had the type of rally that he taught #trump to have with #maga. it’s a #putin rally taught to #trump and his
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q7747 putin  => Vladimir Putin <2nd and 4th President of Russia>
# https://www.wikidata.org/wiki/Q190087 type  => data type <classification of data in computer science>
# https://www.wikidata.org/wiki/Q175331 rally  => demonstration <collective action by people in favor of a cause>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q65066570 maga  => Maga <>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q175331 rally  => demonstration <collective action by people in favor of a cause>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# how one republican is struggling to get to yes on biden’s big deal  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q55668409 republican  => Westfield Republican <newspaper published in Westfield, New York>
# https://www.wikidata.org/wiki/Q4905560 big,deal  => Big Deal <British television comedy/drama series>
# https://www.wikidata.org/wiki/Q15980607 biden  => 2012 VP113 <Trans-Neptunian object>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# when i see references to hunter biden and #arresthunter  i believe it means someone in #trump world is in deep trou
# https://www.wikidata.org/wiki/Q121769 references  => reference <relation between objects in which one object designates, or acts as a means by which to connect to or link to, another object>
# https://www.wikidata.org/wiki/Q5944264 hunter,biden  => Hunter Biden <son of former Vice President of the United States Joe Biden>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q16502 world  => world <planet Earth and all life upon it, including human civilization>
#
# @jtruss21 @sunflwrgirl2 @katibug817 @beachlifelinda1 @real_chatty_cat @omega7stone @simonjester007 @brittanyintexas
#
# @itshammertimeii #mccarthy was told by #pelosi but guess kevin didn’t pass that onto  #theoutsiderone in the pock
# https://www.wikidata.org/wiki/Q590790 mccarthy  => McCarthy <Small community in southeast Alaska>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q47544271 pelosi  => Pelosi <family name>
# https://www.wikidata.org/wiki/Q357984 kevin  => None <Belgian association football player>
# https://www.wikidata.org/wiki/Q21452657 pock  => Pock <family name>
#
# just in case you were wondering if these people are completely insane and deluded  here you go  #trump #maga #gqp
# https://www.wikidata.org/wiki/Q8188561 case  => letter case <property of a letter in bicameral alphabets (most notably the Latin one); piece of information whether a letter is taller "upper case" or lower "lower case">
# https://www.wikidata.org/wiki/Q5 people  => human <common name of Homo sapiens, unique extant species of the genus Homo>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# why trump can't resist running in 2024    #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
#
# #stopthesteal (via a coordinated media suppressive scheme) was very real.  the election was stolen by various for
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q959962 scheme  => diagram <plan, drawing, sketch or outline to show how something works or the relationships between the parts of a whole>
# https://www.wikidata.org/wiki/Q1740954 media  => tunica media <middle layer of blood vessel>
# https://www.wikidata.org/wiki/Q40231 election  => election <process by which a population chooses an individual to hold public office>
#
# @iamsteveharvey everything said by #republicans  #gop  @gop  #trump #desantis @rondesantisfl @sentedcruz  shall i go on
# https://www.wikidata.org/wiki/Q29468 republicans  => Republican Party <political party in the United States>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q29468 gop  => Republican Party <political party in the United States>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q56244080 desantis  => DeSantis <family name>
#
# the @nytimes just admitted that it participated in an effort to rig the election for joe biden. #trump #donaldtrump
# https://www.wikidata.org/wiki/Q14536140 effort  => exertion <use of physical or perceived energy by a person>
# https://www.wikidata.org/wiki/Q40231 election  => election <process by which a population chooses an individual to hold public office>
# https://www.wikidata.org/wiki/Q6279 joe,biden  => Joe Biden <47th Vice President of the United States (in office from 2009 to 2017)>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# mccarthy plans to strip democrats off committees  #maga #trump2024 #trump
# https://www.wikidata.org/wiki/Q590790 mccarthy  => McCarthy <Small community in southeast Alaska>
# https://www.wikidata.org/wiki/Q29552 democrats  => Democratic Party <political party in the United States>
# https://www.wikidata.org/wiki/Q865588 committees  => committee <body of one or more persons that is subordinate to a deliberative assembly>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
#
# of course no wars  wall  jobs and a great economy so lets not elect  #trump who got results and instead install
# https://www.wikidata.org/wiki/Q7078742 of,course  => Of Course <episode of How I Met Your Mother (S5 E17)>
# https://www.wikidata.org/wiki/Q1962728 course  => course <direction or route along which an object travels>
# https://www.wikidata.org/wiki/Q192581 jobs  => job <an activity done by a person to earn money>
# https://www.wikidata.org/wiki/Q42948 wall  => wall <vertical structure, usually solid, that defines and sometimes protects an area>
# https://www.wikidata.org/wiki/Q159810 economy  => economy <an area of the production, distribution and trade, as well as consumption of goods and services by different agents.>
# https://www.wikidata.org/wiki/Q727407 trump  => trump <playing card with a higher rank>
# https://www.wikidata.org/wiki/Q278485 #  => hashtag <word or an unspaced phrase prefixed with the number sign, used to categorise a topic>
# https://www.wikidata.org/wiki/Q2995644 results  => result <final consequence of a sequence of actions or events>
